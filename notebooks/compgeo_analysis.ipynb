# %% [markdown]
# ## Categorize CompGeo submissions (Part 1)
# Distinguish between 'experimental', 'computational' and 'other'.

# %%
# !python ../scripts/analysis.py -i ..\scripts\compgeo.csv -o ..\results\compgeo_exp_vs_comp.csv -c ..\categories\categories_experimental_vs_computational.csv -oa ..\categories\oa_scores.csv -da ..\categories\da_scores.csv
# Out:
# INFO: Read 1000 rows from compgeo.csv
# INFO: [0] Fetching https://link.springer.com/article/10.1007/s10596-025-10380-8
# INFO: [1] Fetching https://link.springer.com/article/10.1007/s10596-025-10379-1
# INFO: [2] Fetching https://link.springer.com/article/10.1007/s10596-025-10374-6
# INFO: [3] Fetching https://link.springer.com/article/10.1007/s10596-025-10373-7
# INFO: [4] Fetching https://link.springer.com/article/10.1007/s10596-025-10378-2
# INFO: [5] Fetching https://link.springer.com/article/10.1007/s10596-025-10376-4
# INFO: [6] Fetching https://link.springer.com/article/10.1007/s10596-025-10375-5
# INFO: [7] Fetching https://link.springer.com/article/10.1007/s10596-025-10371-9
# INFO: [8] Fetching https://link.springer.com/article/10.1007/s10596-025-10372-8
# INFO: [9] Fetching https://link.springer.com/article/10.1007/s10596-025-10369-3
# INFO: [10] Fetching https://link.springer.com/article/10.1007/s10596-025-10366-6
# ...

# %% [markdown]
# ## Categorize CompGeo submissions (Part 2)
# Distinguish between 'imaging', 'simulation' and 'other'.

# %%
# !python ../scripts/analysis.py -i ..\scripts\compgeo.csv -o ..\results\compgeo_img_vs_sim.csv -c ..\categories\categories_imaging_vs_simulation.csv -oa ..\categories\oa_scores.csv -da ..\categories\da_scores.csv
# Out:
# INFO: Read 1000 rows from compgeo.csv
# INFO: [0] Fetching https://link.springer.com/article/10.1007/s10596-025-10380-8
# INFO: [1] Fetching https://link.springer.com/article/10.1007/s10596-025-10379-1
# INFO: [2] Fetching https://link.springer.com/article/10.1007/s10596-025-10374-6
# INFO: [3] Fetching https://link.springer.com/article/10.1007/s10596-025-10373-7
# INFO: [4] Fetching https://link.springer.com/article/10.1007/s10596-025-10378-2
# INFO: [5] Fetching https://link.springer.com/article/10.1007/s10596-025-10376-4
# INFO: [6] Fetching https://link.springer.com/article/10.1007/s10596-025-10375-5
# INFO: [7] Fetching https://link.springer.com/article/10.1007/s10596-025-10371-9
# INFO: [8] Fetching https://link.springer.com/article/10.1007/s10596-025-10372-8
# INFO: [9] Fetching https://link.springer.com/article/10.1007/s10596-025-10369-3
# INFO: [10] Fetching https://link.springer.com/article/10.1007/s10596-025-10366-6
# ...
