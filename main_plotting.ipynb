# %% [markdown]
# ## Plotting of results of the TiPM analysis

# %%
#input_stem = "tipm_exp_vs_comp"
#categories = ["experimental", "computational"]
input_stem = "tipm_img_vs_sim"
categories = ["imaging", "simulation"]

# %%
# !python plotting.py -i .\results\{input_stem}.csv -c {" ".join(categories)}
# Out:
# Figure(640x480)
# Figure(640x480)
# Figure(800x500)
# Figure(800x500)
# Figure(1200x400)
# Figure(1200x400)
# Figure(640x480)
# Figure(640x480)
# c:\Users\jbo062\src\data-projects\code_and_data_availability\plotting.py:128: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   trend_paper = df.groupby(["Period", paper_col]).size().unstack(fill_value=0)
# c:\Users\jbo062\src\data-projects\code_and_data_availability\plotting.py:183: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   trend_data = df.groupby(["Period", data_col]).size().unstack(fill_value=0)

# %%
from IPython.display import Image, display
import os

# Define the input file stem and output folder
output_folder = "results"

# List of expected figure suffixes
figure_suffixes = [
    "category_distribution.png",
    "subcategory_distribution.png",
    "subcategory_per_year.png",
    "category_per_year.png",
    "relative_article_availability.png",
    "relative_data_availability.png",
    "paper_availability_pies.png",
    "data_availability_pies.png",
]

# Display each figure inline
for suffix in figure_suffixes:
    fig_path = os.path.join(output_folder, f"{input_stem}_{suffix}")
    if os.path.exists(fig_path):
        display(Image(filename=fig_path))
    else:
        print(f"Figure not found: {fig_path}")
